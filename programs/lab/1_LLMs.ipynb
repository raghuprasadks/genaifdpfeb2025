# %% [markdown]
# #Packages

# %%
#LLMs Lab-1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Accessing OpenAI LLM through an API

# %%
# !pip install OpenAI -q
# !pip install langchain  -q
# !pip install langchain_community  -q
# !pip install Cohere  -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.8 MB/s eta 0:00:00

# %%
import os

from google.colab import userdata
COHERE_API_KEY = userdata.get("COHERE_API_KEY")

#os.environ['OPENAI_API_KEY'] = "Your Key"
os.environ['COHERE_API_KEY'] = COHERE_API_KEY

import warnings
warnings.filterwarnings('ignore')

# %%
from langchain.llms import OpenAI, Cohere

#llm= OpenAI()
llm=Cohere()
print(llm.invoke("How many minimum sleeping hours you should have?"))
# Out:
# <ipython-input-6-f5e96ef51b37>:4: LangChainDeprecationWarning: The class `Cohere` was deprecated in LangChain 0.1.14 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-cohere package and should be used instead. To use it run `pip install -U :class:`~langchain-cohere` and import as `from :class:`~langchain_cohere import Cohere``.
#   llm=Cohere()
#  According to the Centers for Disease Control and Prevention (CDC), seven or more hours of sleep per night is recommended for adults ages 18-60. However, it is important to note that sleep needs vary from person to person, and you may need more or less sleep depending on various factors such as age, lifestyle, and overall health.
#
# If you want to determine your optimal sleep duration, you should monitor your energy levels and cognitive function throughout the day and experiment with different sleep durations until you find the sweet spot that works best for you.
#
# It is also essential to prioritize quality sleep, which means cultivating healthy sleep habits such as a quiet, dark, and comfortably cool sleep environment and practicing pre-sleep routines such as winding down activities and limiting exposure to electronic devices.
#
# Doing these things helps you get the most out of your sleep and ensure your body is well-rested and energized for the next day.

# %%
print(llm.invoke("What is the sentiment of this review. Give one word answer Pos or Neg - The staff was friendly and helpful. I had a great experience with my loan officer."))
# Out:
#  Pos

# %%
import pandas as pd

# Create a list of log messages
log_messages = [
    "INFO: Server started successfully",
    "WARNING: Low disk space",
    "CRITICAL: Database connection failed",
    "CRITICAL: Security breach detected",
    "INFO: New feature released",
]

# Create a DataFrame with 10 rows and 1 column
df = pd.DataFrame(log_messages, columns=["Message"])

# %%
df
# Out:
#                                 Message
# 0     INFO: Server started successfully
# 1               WARNING: Low disk space
# 2  CRITICAL: Database connection failed
# 3    CRITICAL: Security breach detected
# 4            INFO: New feature released

# %%
# Classify each log message using llm.invoke
df["Sentiment"] = df["Message"].apply(lambda message: llm.invoke(f"Classify the severity of this log message make give output as CRITICAL if the message is critical: {message}"))

# %%
df
# Out:
#                                 Message  \
# 0     INFO: Server started successfully
# 1               WARNING: Low disk space
# 2  CRITICAL: Database connection failed
# 3    CRITICAL: Security breach detected
# 4            INFO: New feature released
#
#                                            Sentiment
# 0                                               INFO
# 1   The severity of the log message "WARNING: Low...
# 2                                           CRITICAL
# 3                                           CRITICAL
# 4   The severity of the log message "INFO: New fe...

# %% [markdown]
# # Gen AI - Code Generation in Google Colab

# %% [markdown]
# Import dataset from https://raw.githubusercontent.com/venkatareddykonasani/Datasets/master/Automobile%20Data%20Set/AutoDataset.csv

# %% [markdown]
# print number of rows and columns

# %% [markdown]
# Print the column names

# %% [markdown]
# Create a bar chart for the 'fuel-type' column

# %% [markdown]
# Findout outliers in price column
